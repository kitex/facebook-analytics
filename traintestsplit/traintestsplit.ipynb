# %%
import sqlite3
import pandas as pd
import numpy as np
import re

connection = sqlite3.connect('E:\\python\\notebook\\course3_downloads\\feed.db')
cursor = connection.cursor()
test_done = False
limit = 5000
cur_length = limit


df = pd.read_sql("""select m.status_message quest,c.status_message cmt from comment c
                left join main_post m
                on 
                c.post_id = m.status_id
                where m.status_message <> ""
                order by c.post_id limit {}
                """.format(limit), connection)


msk = np.random.rand(len(df)) < 0.8
df = df.replace('\n',' ', regex=True).replace('\r',' ',regex=True).replace('"',"'")
train = df[msk]

test = df[~msk]

# %%
pd.set_option('display.max_colwidth', -1)
print(len(test),len(train))
display(test)
# Out:
# 611 2419
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       quest  \
# 4     ग्राहक सेवाको लागि काठमाडौँ उपत्यका भित्रका कुमारीपाटी, दरबारमार्ग, महाराजगंज, कृष्ण टावर, चाबहिल, बनेपा तथा उपत्यका बाहिरका सम्पूर्ण एनसेल सेन्टरहरु सुचारू भएका छन् । सेन्टरहरूबाट तपाईंले नयाँ सिम कार्ड, रिचार्ज कार्ड, सिम परिवर्तन, कल विवरण लगायतका सम्पूर्ण सेवा प्राप्त गर्न सक्नुहुनेछ। थप जानकारी: http://bit.ly/NcellCentres
# 16    Hello NCELL maile ncell sim Malaysia liara aakochhu yaha ncell sim active hudain?
# 18    सम्पूर्ण स्मार्टफोन प्रयोगकर्ताका लागि ब्याकग्राउण्ड डाटा रोक्ने उपायबारे http://bit.ly/1yTkM7N
# 23    Call your friends, family and associates in the UK at just Rs. 4.99/min (excl. of taxes).  To call, dial 0044 and then the destination number. For more information, dial 4444.
# 27    Ncell u r the best in Nepal.So think that  ntg  is their in the compering with u so i also use to use ncell.you r the best......9804064883
# 28    #NcellFamily टप २० र लेटेस्ट PRBT का साथ रहनुहोस् updated. http://bit.ly/1CnwYKR
# 32    अनलिमिटेड प्याकेज ल्याउँदै एनसेल
# 37    No result??
# 46    #Facts How many times do you check your phone in a day? Are you above or below average?  Follow us on Instagram: www.instagram.com/Ncell
# 54    Nowdays what happen network is not proper
# 55    Since couple of days NCELL network is too slow..Network is dropping continuosly.its totally irritating..Fix the problem ASAP.
# 59    It's Friendship Day today. Wish your friends with friendship messages. Type SATHI and send it to 8888 for just Rs. 2/day (Rs. 2.51 with government taxes).  Happy Friendship Day!
# 60    This is so pathetic... As i am loyal costumer of NCELL network since it was mero mobile once ago... Actully i am frequently facing this problem.... today i am very angry and gonna write this i know you people damn care about what i write and don't give me suggestions what to do..... So here is my point why i am posting this: TODAY I PURCHASED A RECHARGE CARD FROM LOACAL SHOP AT NEARLY 1PM I CAME HOME TAKING RECHARGE CARD AND DID RECHARGE BUT WHAT MESSAGE DISPLAYED AFTER PROCESSING USSD CODE YOU PEOPLE CANT EVEN IMAGINE EVEN I DIDNT EXPECTED . THE MESSAGE WAS " THE RECHARGE NUMBER YOU. ENTERED IS ALREADY BEING USED " I WAS LIKE WTF MAN I JUST PURCHASED AND TH
# 111   सम्पूर्ण स्मार्टफोन प्रयोगकर्ताका लागि ब्याकग्राउण्ड डाटा रोक्ने उपायबारे http://bit.ly/1yTkM7N
# 112   why can not buy data packfrom ncell bonus?
# 116   Yo fb ko dheli data kasari hataune ho ni
# 117   From today, browsing our official website www.ncell.com.np and other official portals like Ecare, PRBT directing from the Ncell site is absolutely free on our network.   Please note that external links like YouTube videos, third party websites will be charged as per the standard data rates.
# ...
# 61    I have some tourism promotional videos which had already edited and also exhibit some where in national and international countries. may i submit this videos? or may i contact you directly in yr office. I know my job is automatically dedicate for country so we can make it much better together.
# 64    Dial *17123# and follow instructions.
# 67    Where is video submitted field i cannot find video submitted area please kindley
# 77    We're working on the network issue and it will be solved soon. Please disable your background data and auto updates while using facebook pack.
# 78    where I can found that...and submit entry
# 91    Ncell k ho yasto network,call majjale janxa na sound aauxa na call katinxa paisa matra katxa,kaati complain garne ho?? 2,3 times mail nai garisake,80m ma tower xa tai ni tower khattam xa,please solve it...9818100907.
# 92    Please upload your file in Dropbox or Google drive and share the public link with us.
# 97    bhimphedi makwanpur word 2 bajar ma 3G network samsya vayeko dherai vo samadhan ko nau maa jhutho aaswasan matra
# 98    Net ma kun website ma herne
# 103   same here haneshthan
# 105   malai offer chahi daina,  bonus chahi daina,  malai ncell ko network chahin6  network problem kahile samma jyaan lin6a
# 110   Ava unlimited pack liyepani kunai faida nahune vo ni ava 1 Gb 3Gb wa 10Gb sakiyepaxi 32kbps ko speed maa chalx k garnu tettiko speed le ta keini hudaina. @Ncell
# 111   Hello ncell can i get my old number that i have lost but that's was my first number. I lost nearly 4 yrs ago. But i want same number.  Can i get or not?
# 112   You can not purchase data pack with bonus balance.
# 116   Please dial *17115# and deactivate the data pack you had subscribed.
# 117   Is ncell app free or not?
# 120   Offer chhaina?
# ...              ...
# 2871  Please dial +960 or 00960 followed by desired mobile number and make a call. Including taxes, tariff rate is Rs 18.65 per minute (for Pro) and Rs 26.10 per minute (for Prepaid).
# 2877  seriouslyyyyyy :D thankxxxx #ncell. . .ticket chai kasari paune hau???
# 2881  Ali Asgar
# 2884  Aarey yaar my 5 service  activate garexi call rate is Rs1.23 per minute.
# 2888  silver ticket ko prize kati ho ?
# 2894  Ghar mai wifi xa pack le ya ra k kam yr
# 2899  Very Sad to Know this Dear Ncell.... I can Understand the pain u had gone with to disclose about the Cancellation of Purplefest  Irresponsible Govt.... ask for compensation for damaging ur goodwill..... Stay Strong
# 2900  Please dial 9007 through your number for the details.
# 2901  Once it is transferred to Pro plan, you cannot switched back to Prepaid  plan.
# 2904  To activate this offer, dial 17106 for free. More at http://www.ncell.com.np/Services/Messaging/Mazzako-SMS
# 2910  If you are experiencing SMS sending problem in Ncell SIM, please dial #330*0000# to cancel the call barring and after that, please set your SMS setting as: Message centre no.: +9779800009000 Reply via same centre: yes Message sent as: text Delivery report : Yes Service in use : GSM Info service: Off Text Support: Full
# 2921  Twitter free भनेको होइन ? खोई त मेरोमा त चलेन त ? 2/4 दिन भएको थियो जीरो balance भएको अहिले त चल्नै छोड्यो । no. 9816221710
# 2922  K ma sajilo tyarif ko bary jankari pauna sakxu
# 2927  Please message us your mobile number with details.
# 2928  Sorry, this service is not available for now.
# 2954  Ncell teti ramro chaldain kaski mijure ma kina ho?
# 2956  Background data restrict kasari garne,nagare k hunxa
# 2965  After consumption of 1 GB ncell pack.. speed katii maa chlaxaa aanii net???
# 2966  Rs.20
# 2967  Dear ncell i wan to buy new sim card at i wan to put number 333444555 how
# 2972  4 ncell 2/3 mahina aagadi saudi phone garna 7 rs/ minut lagthyo hami harulai ek dam rahat thiyo aaj kal aayera 20 rs/ minut katxa kina hola pahile jastai subidha diye aabhari hune thiyeu
# 2974  Prachar garne ni dami-dami idea nikalxa ncell le! :-D ;-)
# 2975  Say all the information about corporate sim.
# 2979  Sms vand cal ma free vaya aja ramro hunethyo ncl.
# 2980  yoo sewa free ho ....???
# 2994  Maile pani sms paena..
# 3007  customer care ma call receive kina hunna #ncell
# 3010  There was no free viber n Skype just few minute before i loaded 100 recharge card whiteout talking 20 rs finish n I use few minut viber then finish my all balance is it facility from NCELL is really fuck off
# 3020  how do active 3g net
# 3028  Please message us your mobile number to be recharged.
#
# [611 rows x 2 columns]

# %%
np.set_printoptions(threshold=np.nan)
test['quest'][:5]
# Out:
# 4     ग्राहक सेवाको लागि काठमाडौँ उपत्यका भित्रका कुमारीपाटी, दरबारमार्ग, महाराजगंज, कृष्ण टावर, चाबहिल, बनेपा तथा उपत्यका बाहिरका सम्पूर्ण एनसेल सेन्टरहरु सुचारू भएका छन् । सेन्टरहरूबाट तपाईंले नयाँ सिम कार्ड, रिचार्ज कार्ड, सिम परिवर्तन, कल विवरण लगायतका सम्पूर्ण सेवा प्राप्त गर्न सक्नुहुनेछ। थप जानकारी: http://bit.ly/NcellCentres
# 16    Hello NCELL maile ncell sim Malaysia liara aakochhu yaha ncell sim active hudain?
# 18    सम्पूर्ण स्मार्टफोन प्रयोगकर्ताका लागि ब्याकग्राउण्ड डाटा रोक्ने उपायबारे http://bit.ly/1yTkM7N
# 23    Call your friends, family and associates in the UK at just Rs. 4.99/min (excl. of taxes).  To call, dial 0044 and then the destination number. For more information, dial 4444.
# 27    Ncell u r the best in Nepal.So think that  ntg  is their in the compering with u so i also use to use ncell.you r the best......9804064883
# Name: quest, dtype: object

# %%
with open('test.from', 'a', encoding='utf8') as f:
    for content in test['quest'].values:
        #print(content)
        f.write(content + '\n')

with open('test.to', 'a', encoding='utf8') as f:
    for content in test['cmt'].values:
        f.write(str(content) + '\n')

with open('train.from', 'a', encoding='utf8') as f:
    for content in train['quest'].values:
        f.write(content + '\n')

with open('train.to', 'a', encoding='utf8') as f:
    for content in train['cmt'].values:
        f.write(str(content) + '\n')
print("Write successful...")
# Out:
# Write successful...
